# %%
import os
from pathlib import Path
import calendar
import logging
import xarray as xr
import pandas as pd

logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s:%(message)s')


BASE = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
RAW_DIR = BASE / "data" / "raw" / "era5"
PROCESSED_DIR = BASE / "data" / "processed"
RAW_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

# ERA5 bounding box (Dwarka / Delhi area) - [north, west, south, east]
ERA5_AREA = [28.9, 76.8, 28.4, 77.4]

# %%
import cdsapi
c = cdsapi.Client()

years = ['2018','2019','2020','2021','2022','2023']
for year in years:
    for month in range(1, 13):
        outf = RAW_DIR / f"delhi_weather_{year}_{month:02d}.nc"
        if outf.exists():
            logging.info("File exists, skipping: %s", outf.name)
            continue
        days_in_month = calendar.monthrange(int(year), month)[1]
        logging.info("Requesting %s-%02d", year, month)
        try:
            c.retrieve(
                'reanalysis-era5-single-levels',
                {
                    'product_type': 'reanalysis',
                    'variable': ['2m_temperature', '2m_dewpoint_temperature'],
                    'year': year,
                    'month': f"{month:02d}",
                    'day': [f"{d:02d}" for d in range(1, days_in_month + 1)],
                    'time': [f"{h:02d}:00" for h in range(24)],
                    'area': ERA5_AREA,
                    'format': 'netcdf',
                },
                str(outf)
            )
            logging.info("Downloaded %s", outf.name)
        except Exception as e:
            logging.error("Download failed for %s-%02d: %s", year, month, e)
            # continue to next month

# %%
# Cell 0: Setup paths and logging (MUST RUN FIRST)
from pathlib import Path
import logging
import pandas as pd
import xarray as xr

logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s:%(message)s")


BASE_DIR = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()

RAW_DIR = BASE_DIR / "data" / "raw" / "era5"
PROCESSED_DIR = BASE_DIR / "data" / "processed"

RAW_DIR.mkdir(parents=True, exist_ok=True)
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)

print("RAW_DIR:", RAW_DIR)
print("PROCESSED_DIR:", PROCESSED_DIR)
# Out:
# RAW_DIR: /Users/panavdawar/Documents/resilienceAI /data/raw/era5
# PROCESSED_DIR: /Users/panavdawar/Documents/resilienceAI /data/processed

# %%
import glob

nc_files = sorted(glob.glob(str(RAW_DIR / "delhi_weather_*.nc")))
logging.info("Found %d netcdf files", len(nc_files))

dfs = []
for f in nc_files:
    logging.info("Opening %s", f)
    ds = xr.open_dataset(f)
    # select variables if present
    var_names = list(ds.data_vars)
    # typical names: 't2m' and 'd2m' or '2m_temperature' depending on file
    # try to standardize
    if 't2m' in var_names and 'd2m' in var_names:
        ds_sel = ds[['t2m','d2m']]
    else:
        # fallback to known variable labels
        # try common alternatives
        alt = {k:k for k in var_names if k in ['t2m','d2m','2m_temperature','2m_dewpoint_temperature']}
        if len(alt) >= 2:
            ds_sel = ds[list(alt.keys())]
        else:
          
            ds_sel = ds[list(var_names)[:2]]
    ds_sel = ds_sel.load()  
    df = ds_sel.to_dataframe().reset_index()

    rename_map = {}
    if 't2m' in df.columns:
        rename_map['t2m'] = 'temp'
    elif '2m_temperature' in df.columns:
        rename_map['2m_temperature'] = 'temp'
    if 'd2m' in df.columns:
        rename_map['d2m'] = 'dewpoint'
    elif '2m_dewpoint_temperature' in df.columns:
        rename_map['2m_dewpoint_temperature'] = 'dewpoint'
    df = df.rename(columns=rename_map)

    keep_cols = [c for c in ['time','latitude','longitude','temp','dewpoint'] if c in df.columns]
    df = df[keep_cols]
    dfs.append(df)

if len(dfs) == 0:
    raise RuntimeError("No NetCDF files found. Put them in data/raw/era5/")
data = pd.concat(dfs, ignore_index=True)

if 'time' in data.columns:
    data = data.rename(columns={'time':'datetime','latitude':'lat','longitude':'lon'})

if data['temp'].max() > 100:
    data['temp'] = data['temp'] - 273.15
if data['dewpoint'].max() > 100:
    data['dewpoint'] = data['dewpoint'] - 273.15


out_csv = PROCESSED_DIR / "delhi_weather_combined.csv"
data.to_csv(out_csv, index=False)
logging.info("Saved combined CSV: %s (rows=%d)", out_csv, len(data))
# Out:
# 2026-01-22 11:09:13,030 INFO:Found 72 netcdf files
# 2026-01-22 11:09:13,031 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_01.nc
# 2026-01-22 11:09:13,205 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_02.nc
# 2026-01-22 11:09:13,215 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_03.nc
# 2026-01-22 11:09:13,226 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_04.nc
# 2026-01-22 11:09:13,235 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_05.nc
# 2026-01-22 11:09:13,244 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_06.nc
# 2026-01-22 11:09:13,254 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_07.nc
# 2026-01-22 11:09:13,264 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_08.nc
# 2026-01-22 11:09:13,273 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_09.nc
# 2026-01-22 11:09:13,283 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_10.nc
# 2026-01-22 11:09:13,293 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_11.nc
# 2026-01-22 11:09:13,303 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2018_12.nc
# 2026-01-22 11:09:13,312 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_01.nc
# 2026-01-22 11:09:13,321 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_02.nc
# 2026-01-22 11:09:13,329 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_03.nc
# 2026-01-22 11:09:13,339 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_04.nc
# 2026-01-22 11:09:13,349 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_05.nc
# 2026-01-22 11:09:13,360 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_06.nc
# 2026-01-22 11:09:13,369 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_07.nc
# 2026-01-22 11:09:13,379 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_08.nc
# 2026-01-22 11:09:13,389 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_09.nc
# 2026-01-22 11:09:13,399 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_10.nc
# 2026-01-22 11:09:13,409 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_11.nc
# 2026-01-22 11:09:13,419 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2019_12.nc
# 2026-01-22 11:09:13,429 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_01.nc
# 2026-01-22 11:09:13,447 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_02.nc
# 2026-01-22 11:09:13,461 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_03.nc
# 2026-01-22 11:09:13,472 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_04.nc
# 2026-01-22 11:09:13,484 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_05.nc
# 2026-01-22 11:09:13,494 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_06.nc
# 2026-01-22 11:09:13,505 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_07.nc
# 2026-01-22 11:09:13,517 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_08.nc
# 2026-01-22 11:09:13,527 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_09.nc
# 2026-01-22 11:09:13,536 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_10.nc
# 2026-01-22 11:09:13,546 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_11.nc
# 2026-01-22 11:09:13,556 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2020_12.nc
# 2026-01-22 11:09:13,566 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_01.nc
# 2026-01-22 11:09:13,576 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_02.nc
# 2026-01-22 11:09:13,586 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_03.nc
# 2026-01-22 11:09:13,595 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_04.nc
# 2026-01-22 11:09:13,604 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_05.nc
# 2026-01-22 11:09:13,613 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_06.nc
# 2026-01-22 11:09:13,622 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_07.nc
# 2026-01-22 11:09:13,631 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_08.nc
# 2026-01-22 11:09:13,640 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_09.nc
# 2026-01-22 11:09:13,649 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_10.nc
# 2026-01-22 11:09:13,658 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_11.nc
# 2026-01-22 11:09:13,666 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2021_12.nc
# 2026-01-22 11:09:13,675 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_01.nc
# 2026-01-22 11:09:13,684 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_02.nc
# 2026-01-22 11:09:13,692 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_03.nc
# 2026-01-22 11:09:13,701 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_04.nc
# 2026-01-22 11:09:13,709 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_05.nc
# 2026-01-22 11:09:13,718 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_06.nc
# 2026-01-22 11:09:13,727 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_07.nc
# 2026-01-22 11:09:13,736 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_08.nc
# 2026-01-22 11:09:13,747 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_09.nc
# 2026-01-22 11:09:13,758 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_10.nc
# 2026-01-22 11:09:13,767 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_11.nc
# 2026-01-22 11:09:13,777 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2022_12.nc
# 2026-01-22 11:09:13,786 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_01.nc
# 2026-01-22 11:09:13,794 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_02.nc
# 2026-01-22 11:09:13,803 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_03.nc
# 2026-01-22 11:09:13,812 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_04.nc
# 2026-01-22 11:09:13,821 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_05.nc
# 2026-01-22 11:09:13,830 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_06.nc
# 2026-01-22 11:09:13,839 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_07.nc
# 2026-01-22 11:09:13,847 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_08.nc
# 2026-01-22 11:09:13,856 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_09.nc
# 2026-01-22 11:09:13,865 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_10.nc
# 2026-01-22 11:09:13,874 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_11.nc
# 2026-01-22 11:09:13,883 INFO:Opening /Users/panavdawar/Documents/resilienceAI /data/raw/era5/delhi_weather_2023_12.nc
# 2026-01-22 11:09:14,901 INFO:Saved combined CSV: /Users/panavdawar/Documents/resilienceAI /data/processed/delhi_weather_combined.csv (rows=473256)
